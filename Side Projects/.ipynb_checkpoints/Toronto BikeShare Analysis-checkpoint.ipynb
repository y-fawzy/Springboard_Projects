# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
import datetime

# %%
r1 = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information')
r2 = requests.get('https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status')

# %%
station_info = r1.json()
station_status = r2.json()

# %%
station_info
# Out:
# {'last_updated': 1562734990,
#  'ttl': 30,
#  'data': {'stations': [{'station_id': '7000',
#     'name': 'Fort York  Blvd / Capreol Ct',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.639832,
#     'lon': -79.395954,
#     'altitude': 0.0,
#     'address': 'Fort York  Blvd / Capreol Ct',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9607'},
#    {'station_id': '7001',
#     'name': 'Lower Jarvis St / The Esplanade',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.647992,
#     'lon': -79.370907,
#     'altitude': 0.0,
#     'address': 'Lower Jarvis St / The Esplanade',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-617-9576'},
#    {'station_id': '7002',
#     'name': 'St. George St / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.667333,
#     'lon': -79.399429,
#     'altitude': 0.0,
#     'address': 'St. George St / Bloor St W',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9615'},
#    {'station_id': '7003',
#     'name': 'Madison Ave / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.667158,
#     'lon': -79.402761,
#     'altitude': None,
#     'address': 'Madison Ave / Bloor St W',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-631-4587'},
#    {'station_id': '7004',
#     'name': 'University Ave / Elm St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656518,
#     'lon': -79.389099,
#     'altitude': None,
#     'address': 'University Ave / Elm St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9673'},
#    {'station_id': '7005',
#     'name': 'King St W / York St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6480008,
#     'lon': -79.383177,
#     'altitude': 0.0,
#     'address': 'King St W / York St',
#     'capacity': 16,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9693'},
#    {'station_id': '7006',
#     'name': 'Bay St / College St (East Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660439,
#     'lon': -79.385525,
#     'altitude': 0.0,
#     'address': 'Bay St / College St (East Side)',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-569-2349'},
#    {'station_id': '7007',
#     'name': 'College St / Huron St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.658148,
#     'lon': -79.398167,
#     'altitude': 0.0,
#     'address': 'College St / Huron St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-625-3582'},
#    {'station_id': '7008',
#     'name': "Wellesley St / Queen's Park Cres",
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663376,
#     'lon': -79.392125,
#     'altitude': 0.0,
#     'address': "Wellesley St W / Queen's Park Cres",
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9648'},
#    {'station_id': '7009',
#     'name': 'King St E / Jarvis St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650325,
#     'lon': -79.372287,
#     'altitude': 0.0,
#     'address': 'King St E / Jarvis St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-620-8649'},
#    {'station_id': '7010',
#     'name': 'King St W / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645323,
#     'lon': -79.395003,
#     'altitude': 0.0,
#     'address': 'King St W / Spadina Ave',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-202-6537'},
#    {'station_id': '7011',
#     'name': 'Wellington St W / Portland St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.642982,
#     'lon': -79.399256,
#     'altitude': 0.0,
#     'address': 'Wellington St W / Portland St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-624-4001'},
#    {'station_id': '7012',
#     'name': 'Elizabeth St / Edward St (Bus Terminal)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656026,
#     'lon': -79.385327,
#     'altitude': 0.0,
#     'address': 'Elizabeth St / Edward St (Bus Terminal)',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9665'},
#    {'station_id': '7013',
#     'name': 'Scott St / The Esplanade',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64656,
#     'lon': -79.375274,
#     'altitude': 0.0,
#     'address': 'Scott St / The Esplanade',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-666-6440'},
#    {'station_id': '7014',
#     'name': 'Sherbourne St / Carlton St (Allan Gardens)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663102,
#     'lon': -79.373181,
#     'altitude': 0.0,
#     'address': 'Sherbourne St / Carlton St (Allan Gardens)',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-710-6764'},
#    {'station_id': '7015',
#     'name': 'King St W / Bay St (West Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64852,
#     'lon': -79.380576,
#     'altitude': 0.0,
#     'address': 'King St W / Bay St (West Side)',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-671-7595'},
#    {'station_id': '7016',
#     'name': 'Bay St / Queens Quay W (Ferry Terminal)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640823,
#     'lon': -79.376265,
#     'altitude': 0.0,
#     'address': 'Bay St / Queens Quay W (Ferry Terminal)',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-271-1378'},
#    {'station_id': '7017',
#     'name': 'Widmer St / Adelaide St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.647145,
#     'lon': -79.391479,
#     'altitude': 0.0,
#     'address': 'Widmer St / Adelaide St W',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-631-9958'},
#    {'station_id': '7018',
#     'name': 'Bremner Blvd / Rees St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.641529,
#     'lon': -79.386741,
#     'altitude': 0.0,
#     'address': 'Bremner Blvd / Rees St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-0947'},
#    {'station_id': '7019',
#     'name': 'Temperance St. Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6507021,
#     'lon': -79.3800546,
#     'altitude': 0.0,
#     'address': 'Temperance St. Station',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-203-5761'},
#    {'station_id': '7020',
#     'name': 'Phoebe St / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650033,
#     'lon': -79.396555,
#     'altitude': None,
#     'address': 'Phoebe St / Spadina Ave',
#     'capacity': 33,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-621-5766'},
#    {'station_id': '7021',
#     'name': 'Bay St / Albert St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.653264,
#     'lon': -79.382458,
#     'altitude': 0.0,
#     'address': 'Bay St / Albert St',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9652'},
#    {'station_id': '7022',
#     'name': 'Simcoe St / Queen St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650858,
#     'lon': -79.387582,
#     'altitude': None,
#     'address': 'Simcoe St / Queen St W',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-625-3265'},
#    {'station_id': '7023',
#     'name': 'College St / Borden St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6571,
#     'lon': -79.4056,
#     'altitude': 0.0,
#     'address': 'College St / Borden St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9629'},
#    {'station_id': '7024',
#     'name': 'Dundonald St / Church St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66663,
#     'lon': -79.38148,
#     'altitude': 0.0,
#     'address': 'Dundonald St / Church St',
#     'capacity': 41,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-631-9859'},
#    {'station_id': '7025',
#     'name': 'Ted Rogers Way / Bloor St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671293,
#     'lon': -79.380471,
#     'altitude': 0.0,
#     'address': 'Ted Rogers Way / Bloor St E',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-631-9970'},
#    {'station_id': '7026',
#     'name': 'Bay St / St. Joseph St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.665527,
#     'lon': -79.387499,
#     'altitude': None,
#     'address': 'Bay St / St. Joseph St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-666-0783'},
#    {'station_id': '7027',
#     'name': 'Beverley  St / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652823,
#     'lon': -79.393388,
#     'altitude': 0.0,
#     'address': 'Beverley  St / Dundas St W',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-621-6739'},
#    {'station_id': '7028',
#     'name': 'Gould St / Mutual St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6582,
#     'lon': -79.3768,
#     'altitude': None,
#     'address': 'Gould St / Mutual St',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-560-7261'},
#    {'station_id': '7029',
#     'name': 'St. James Park (King St. E.)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6501624,
#     'lon': -79.3733997,
#     'altitude': 0.0,
#     'address': 'St. James Park (King St. E.)',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-3457'},
#    {'station_id': '7030',
#     'name': 'Bay St / Wellesley St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664088,
#     'lon': -79.387095,
#     'altitude': None,
#     'address': 'Bay St / Wellesley St W',
#     'capacity': 65,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9612'},
#    {'station_id': '7031',
#     'name': 'Jarvis St / Isabella St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.668991,
#     'lon': -79.379385,
#     'altitude': 0.0,
#     'address': 'Jarvis St / Isabella St',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-569-7503'},
#    {'station_id': '7032',
#     'name': 'Augusta Ave / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652473,
#     'lon': -79.401456,
#     'altitude': 0.0,
#     'address': 'Augusta Ave / Dundas St W',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-622-8139'},
#    {'station_id': '7033',
#     'name': 'Union Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645609,
#     'lon': -79.380386,
#     'altitude': 0.0,
#     'address': 'Union Station',
#     'capacity': 26,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-620-1494'},
#    {'station_id': '7034',
#     'name': 'Church St / Bloor St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671389,
#     'lon': -79.382919,
#     'altitude': 0.0,
#     'address': 'Church St / Bloor St E',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-992-7029'},
#    {'station_id': '7035',
#     'name': 'Queen St W / Ossington Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643975,
#     'lon': -79.419576,
#     'altitude': 0.0,
#     'address': 'Queen St W / Ossington Ave',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-371-6632'},
#    {'station_id': '7036',
#     'name': 'Trinity St /Front St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.651318,
#     'lon': -79.36023,
#     'altitude': 0.0,
#     'address': 'Trinity St / Front St E',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-816-5603'},
#    {'station_id': '7037',
#     'name': 'Bathurst St / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6523,
#     'lon': -79.4058,
#     'altitude': 0.0,
#     'address': 'Bathurst St / Dundas St W',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-621-8042'},
#    {'station_id': '7038',
#     'name': 'Dundas St W / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656094,
#     'lon': -79.381484,
#     'altitude': 0.0,
#     'address': 'Dundas St W / Yonge St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9714'},
#    {'station_id': '7039',
#     'name': 'Simcoe St / Dundas St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.653743,
#     'lon': -79.38882,
#     'altitude': None,
#     'address': 'Simcoe St / Dundas St W',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-202-6089'},
#    {'station_id': '7040',
#     'name': 'Euclid Ave / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664467,
#     'lon': -79.414783,
#     'altitude': 0.0,
#     'address': 'Euclid Ave / Bloor St W',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-565-9380'},
#    {'station_id': '7041',
#     'name': 'Edward St / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.656729,
#     'lon': -79.382736,
#     'altitude': None,
#     'address': 'Edward St / Yonge St',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9697'},
#    {'station_id': '7042',
#     'name': 'Sherbourne St / Wellesley St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6673,
#     'lon': -79.374,
#     'altitude': 0.0,
#     'address': 'Sherbourne St / Wellesley St E',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-804-0543'},
#    {'station_id': '7043',
#     'name': 'Queens Quay W / Lower Simcoe St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.63951,
#     'lon': -79.383717,
#     'altitude': 0.0,
#     'address': 'Queens Quay W / Lower Simcoe St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-204-1380'},
#    {'station_id': '7044',
#     'name': 'Church St / Alexander St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663722,
#     'lon': -79.380288,
#     'altitude': 0.0,
#     'address': 'Church St / Alexander St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-618-1341'},
#    {'station_id': '7045',
#     'name': 'Bond St / Queen St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.653236,
#     'lon': -79.376716,
#     'altitude': 0.0,
#     'address': 'Bond St / Queen St E',
#     'capacity': 25,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-629-0639'},
#    {'station_id': '7046',
#     'name': 'Niagara St / Richmond St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64534,
#     'lon': -79.409597,
#     'altitude': 0.0,
#     'address': 'Niagara St / Richmond St W',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9655'},
#    {'station_id': '7047',
#     'name': 'University Ave / Gerrard St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.657763,
#     'lon': -79.389165,
#     'altitude': 0.0,
#     'address': 'University Ave / Gerrard St W',
#     'capacity': 25,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9690'},
#    {'station_id': '7048',
#     'name': 'Front St W / Yonge St (Hockey Hall of Fame)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.646144,
#     'lon': -79.377962,
#     'altitude': 0.0,
#     'address': 'Front St W / Yonge St (Hockey Hall of Fame)',
#     'capacity': 47,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-204-0984'},
#    {'station_id': '7049',
#     'name': 'Queen St W / Portland St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6476,
#     'lon': -79.4015,
#     'altitude': 0.0,
#     'address': 'Queen St W / Portland St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-624-3144'},
#    {'station_id': '7050',
#     'name': 'Richmond St E / Jarvis St Green P',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652634,
#     'lon': -79.374222,
#     'altitude': 0.0,
#     'address': 'Richmond St E / Jarvis St Green P',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-602-5376'},
#    {'station_id': '7051',
#     'name': 'Wellesley St E / Yonge St (Green P)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66506,
#     'lon': -79.38357,
#     'altitude': 0.0,
#     'address': 'Wellesley St E / Yonge St (Green P)',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-587-8911'},
#    {'station_id': '7052',
#     'name': 'Wellington St W / Bay St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.647259,
#     'lon': -79.379878,
#     'altitude': 0.0,
#     'address': 'Wellington St W / Bay St',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-723-3438'},
#    {'station_id': '7053',
#     'name': 'Metro Hall Plaza',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645859,
#     'lon': -79.38783,
#     'altitude': None,
#     'address': 'Metro Hall Plaza',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-201-7794'},
#    {'station_id': '7054',
#     'name': 'Navy Wharf Ct. / Bremner Blvd.',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640722,
#     'lon': -79.391051,
#     'altitude': 0.0,
#     'address': 'Navy Wharf Ct. / Bremner Blvd.',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-662-2516'},
#    {'station_id': '7055',
#     'name': 'Jarvis St / Carlton St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66207,
#     'lon': -79.37617,
#     'altitude': 0.0,
#     'address': 'Jarvis St / Carlton St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-722-3901'},
#    {'station_id': '7056',
#     'name': 'Parliament St / Gerrard St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662132,
#     'lon': -79.3656796,
#     'altitude': 0.0,
#     'address': 'Parliament St / Gerrard St',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-201-5089'},
#    {'station_id': '7057',
#     'name': 'Simcoe St / Wellington St 1',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6461082,
#     'lon': -79.3855266,
#     'altitude': 0.0,
#     'address': 'Simcoe St / Wellington St 1',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-2103'},
#    {'station_id': '7058',
#     'name': 'Huron/ Harbord St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6637,
#     'lon': -79.400053,
#     'altitude': 0.0,
#     'address': 'Huron/ Harbord St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9725'},
#    {'station_id': '7059',
#     'name': 'Front St W / Blue Jays Way',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643473,
#     'lon': -79.390477,
#     'altitude': 0.0,
#     'address': 'Front St W / Blue Jays Way',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-241-7299'},
#    {'station_id': '7060',
#     'name': 'Princess St / Adelaide St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652123,
#     'lon': -79.367139,
#     'altitude': 0.0,
#     'address': 'Princess St / Adelaide St E',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-569-5317'},
#    {'station_id': '7061',
#     'name': 'Bloor St / Brunswick Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.665802,
#     'lon': -79.40731,
#     'altitude': 0.0,
#     'address': 'Bloor St / Brunswick Ave',
#     'capacity': 25,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9676'},
#    {'station_id': '7062',
#     'name': 'University Ave / College St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.659226,
#     'lon': -79.390213,
#     'altitude': None,
#     'address': 'University Ave / College St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9667'},
#    {'station_id': '7063',
#     'name': "Queen's Park / Bloor St W",
#     'physical_configuration': 'REGULAR',
#     'lat': 43.668456,
#     'lon': -79.393899,
#     'altitude': 0.0,
#     'address': "Queen's Park / Bloor St W",
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-632-5491'},
#    {'station_id': '7064',
#     'name': '51 Parliament St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.65205,
#     'lon': -79.362198,
#     'altitude': 0.0,
#     'address': '51 Parliament St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-241-9519'},
#    {'station_id': '7065',
#     'name': 'Dundas St E / Parliament St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.659575,
#     'lon': -79.365769,
#     'altitude': 0.0,
#     'address': 'Dundas St E / Parliament St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-568-2679'},
#    {'station_id': '7066',
#     'name': 'Willcocks St / St. George St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662085,
#     'lon': -79.397735,
#     'altitude': 0.0,
#     'address': 'Willcocks St / St. George St',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9624'},
#    {'station_id': '7067',
#     'name': 'Yonge St / Harbour St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643795,
#     'lon': -79.375413,
#     'altitude': 0.0,
#     'address': 'Yonge St / Harbour St',
#     'capacity': 39,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9613'},
#    {'station_id': '7068',
#     'name': 'Dockside Dr / Queens Quay E (Sugar Beach)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.644607,
#     'lon': -79.366295,
#     'altitude': 0.0,
#     'address': 'Dockside Dr / Queens Quay E (Sugar Beach)',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-999-9028'},
#    {'station_id': '7069',
#     'name': 'Queen St W / Spadina Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.649147,
#     'lon': -79.395504,
#     'altitude': 0.0,
#     'address': 'Queen St W / Spadina Ave',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-622-8344'},
#    {'station_id': '7070',
#     'name': '25 York St – Union Station South',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643667,
#     'lon': -79.380414,
#     'altitude': 0.0,
#     'address': '25 York St – Union Station South',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-624-8596'},
#    {'station_id': '7071',
#     'name': '161 Bleecker St (South of Wellesley)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.666233,
#     'lon': -79.373327,
#     'altitude': 0.0,
#     'address': '161 Bleecker St (South of Wellesley)',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9846'},
#    {'station_id': '7072',
#     'name': 'Queen St W / Shaw St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.644524,
#     'lon': -79.416519,
#     'altitude': 0.0,
#     'address': 'Queen St W / Shaw St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-564-6690'},
#    {'station_id': '7073',
#     'name': 'Spadina Ave / Fort York Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640114,
#     'lon': -79.393249,
#     'altitude': 0.0,
#     'address': 'Spadina Ave / Fort York Blvd',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-627-9646'},
#    {'station_id': '7074',
#     'name': 'Spadina Ave / Sussex Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664137,
#     'lon': -79.402496,
#     'altitude': 0.0,
#     'address': 'Spadina Ave / Sussex Ave',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9718'},
#    {'station_id': '7075',
#     'name': 'Queens Quay W / Dan Leckie Way',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.636533,
#     'lon': -79.395854,
#     'altitude': 0.0,
#     'address': 'Queens Quay W / Dan Leckie Way',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-669-9604'},
#    {'station_id': '7076',
#     'name': 'York St / Queens Quay W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640132,
#     'lon': -79.380464,
#     'altitude': 0.0,
#     'address': 'York St / Queens Quay W',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '416-618-7456'},
#    {'station_id': '7077',
#     'name': 'College Park South',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.659777,
#     'lon': -79.382767,
#     'altitude': 0.0,
#     'address': 'College Park South',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9694'},
#    {'station_id': '7078',
#     'name': 'College St / Major St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6576,
#     'lon': -79.4032,
#     'altitude': 0.0,
#     'address': 'College St / Major St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9638'},
#    {'station_id': '7079',
#     'name': 'McGill St / Church St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660694,
#     'lon': -79.379052,
#     'altitude': 0.0,
#     'address': 'McGill St / Church St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-999-8524'},
#    {'station_id': '7083',
#     'name': 'Danforth Ave / Barrington Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.688325,
#     'lon': -79.300463,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Barrington Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-631-4821'},
#    {'station_id': '7084',
#     'name': 'High Park - Grenadier Cafe',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.645599,
#     'lon': -79.4657123,
#     'altitude': 0.0,
#     'address': 'High Park - Grenadier Cafe',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9563'},
#    {'station_id': '7085',
#     'name': 'Danforth Ave / Westlake Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.687323,
#     'lon': -79.304848,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Westlake Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-201-8853'},
#    {'station_id': '7086',
#     'name': 'High Park - West Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6525077,
#     'lon': -79.4654233,
#     'altitude': 0.0,
#     'address': 'High Park - West Rd',
#     'post_code': '1324',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-7093'},
#    {'station_id': '7087',
#     'name': 'Danforth Ave / Aldridge Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.684758,
#     'lon': -79.316767,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Aldridge Ave',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-9873'},
#    {'station_id': '7088',
#     'name': 'Danforth Ave / Coxwell Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.683378,
#     'lon': -79.322961,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Coxwell Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-248-5891'},
#    {'station_id': '7089',
#     'name': 'Church St  / Wood St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662712,
#     'lon': -79.379903,
#     'altitude': 102.08,
#     'address': 'Church St / Wood St',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-262-1148'},
#    {'station_id': '7090',
#     'name': 'Danforth Ave / Lamb Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.681991,
#     'lon': -79.329455,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Lamb Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-6203'},
#    {'station_id': '7091',
#     'name': 'Donlands Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.681126,
#     'lon': -79.337779,
#     'altitude': 0.0,
#     'address': 'Donlands Station',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-1705'},
#    {'station_id': '7092',
#     'name': 'Pape Subway Green P',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.680223,
#     'lon': -79.344062,
#     'altitude': 0.0,
#     'address': 'Pape Subway Green P',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-3078'},
#    {'station_id': '7093',
#     'name': 'Danforth Ave / Gough Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.678401,
#     'lon': -79.346289,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Gough Ave',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-1671'},
#    {'station_id': '7094',
#     'name': 'Chester Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.678056,
#     'lon': -79.352222,
#     'altitude': 0.0,
#     'address': 'Chester Station',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-638-8374'},
#    {'station_id': '7095',
#     'name': 'Danforth Ave / Ellerbeck St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.677076,
#     'lon': -79.35667,
#     'altitude': 0.0,
#     'address': 'Danforth Ave / Ellerbeck St',
#     'capacity': 14,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-1678'},
#    {'station_id': '7096',
#     'name': 'Boston Ave / Queen St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.661508,
#     'lon': -79.338931,
#     'altitude': 0.0,
#     'address': 'Boston Ave / Queen St E',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-3908'},
#    {'station_id': '7097',
#     'name': 'Riverdale Park North (Broadview Ave)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671172,
#     'lon': -79.354704,
#     'altitude': 0.0,
#     'address': 'Riverdale Park North (Broadview Ave)',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9838'},
#    {'station_id': '7098',
#     'name': 'Riverdale Park South (Broadview Ave)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.667819,
#     'lon': -79.35347,
#     'altitude': 0.0,
#     'address': 'Riverdale Park South (Broadview Ave)',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-640-5291'},
#    {'station_id': '7099',
#     'name': 'Cherry St / Mill St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.651248,
#     'lon': -79.357848,
#     'altitude': 0.0,
#     'address': 'Cherry St / Mill St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-640-7714'},
#    {'station_id': '7100',
#     'name': 'Dundas St E / Regent Park Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.660207,
#     'lon': -79.361275,
#     'altitude': 0.0,
#     'address': 'Dundas St E / Regent Park Blvd',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-3847'},
#    {'station_id': '7101',
#     'name': 'Lower Sherbourne St / The Esplanade',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.648655,
#     'lon': -79.367061,
#     'altitude': 0.0,
#     'address': 'Lower Sherbourne St / The Esplanade',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5818'},
#    {'station_id': '7102',
#     'name': 'Nelson St / Duncan St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.648711,
#     'lon': -79.389728,
#     'altitude': 0.0,
#     'address': 'Nelson St / Duncan St',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5951'},
#    {'station_id': '7103',
#     'name': 'Jimmie Simpson Park (Queen St E)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6605603,
#     'lon': -79.3437663,
#     'altitude': 0.0,
#     'address': 'Jimmie Simpson Park (Queen St E)',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-2521'},
#    {'station_id': '7104',
#     'name': 'King St E / River St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.657071,
#     'lon': -79.356598,
#     'altitude': 0.0,
#     'address': 'King St E / River St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5813'},
#    {'station_id': '7105',
#     'name': 'Queen St E / Sackville St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6561111,
#     'lon': -79.36138888888888,
#     'altitude': 0.0,
#     'address': 'Queen St E / Sackville St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-290-7069'},
#    {'station_id': '7106',
#     'name': 'Mill St / Tannery Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652219,
#     'lon': -79.354455,
#     'altitude': 0.0,
#     'address': 'Mill St / Tannery Rd',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5839'},
#    {'station_id': '7107',
#     'name': 'Cherry St / Distillery Ln',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.650279,
#     'lon': -79.356832,
#     'altitude': 0.0,
#     'address': 'Cherry St / Distillery Ln',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-2608'},
#    {'station_id': '7108',
#     'name': 'Front St E / Cherry St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652686,
#     'lon': -79.358395,
#     'altitude': 0.0,
#     'address': 'Front St E / Cherry St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-4512'},
#    {'station_id': '7109',
#     'name': 'Seaton St / Dundas St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.658777,
#     'lon': -79.369596,
#     'altitude': 0.0,
#     'address': 'Seaton St / Dundas St E',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-3971'},
#    {'station_id': '7110',
#     'name': 'Queen St E / Berkeley St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6552778,
#     'lon': -79.36583333333333,
#     'altitude': 0.0,
#     'address': 'Queen St E / Berkeley St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-290-4392'},
#    {'station_id': '7111',
#     'name': 'King St W / Douro St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640885,
#     'lon': -79.416379,
#     'altitude': 0.0,
#     'address': 'King St W / Douro St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5214'},
#    {'station_id': '7112',
#     'name': 'Liberty St / Fraser Ave Green P',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.637981,
#     'lon': -79.424146,
#     'altitude': 0.0,
#     'address': 'Liberty St / Fraser Ave Green P',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-3920'},
#    {'station_id': '7113',
#     'name': 'Parliament St / Aberdeen Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.665278,
#     'lon': -79.368333,
#     'altitude': 0.0,
#     'address': 'Parliament St / Aberdeen Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-640-5613'},
#    {'station_id': '7114',
#     'name': 'Carlton St / Parliament St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.664524,
#     'lon': -79.36793,
#     'altitude': 0.0,
#     'address': 'Carlton St / Parliament St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-262-2870'},
#    {'station_id': '7115',
#     'name': 'Howard St / Sherbourne St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6712581,
#     'lon': -79.376367,
#     'altitude': 0.0,
#     'address': 'Howard St / Sherbourne St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-1259'},
#    {'station_id': '7116',
#     'name': 'Parliament St / Bloor St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671827,
#     'lon': -79.371849,
#     'altitude': 0.0,
#     'address': 'Parliament St / Bloor St E',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-640-7289'},
#    {'station_id': '7117',
#     'name': 'Castle Frank Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.674083,
#     'lon': -79.368579,
#     'altitude': 0.0,
#     'address': 'Castle Frank Station',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-267-2042'},
#    {'station_id': '7118',
#     'name': 'King St W / Bay St (East Side)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.648575,
#     'lon': -79.380042,
#     'altitude': 0.0,
#     'address': 'King St W / Bay St (East Side)',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-271-6326'},
#    {'station_id': '7119',
#     'name': 'Sumach St / Carlton St. (Riverdale Farm)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.665867,
#     'lon': -79.362506,
#     'altitude': 0.0,
#     'address': 'Sumach St / Carlton St (Riverdale Farm)',
#     'capacity': 14,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-282-9705'},
#    {'station_id': '7120',
#     'name': 'Gerrard St E / River St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.663993,
#     'lon': -79.358534,
#     'altitude': 0.0,
#     'address': 'Gerrard St E / River St',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-643-9843'},
#    {'station_id': '7121',
#     'name': 'Jarvis St / Dundas St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.657266,
#     'lon': -79.374756,
#     'altitude': 0.0,
#     'address': 'Jarvis St / Dundas St E',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-5582'},
#    {'station_id': '7122',
#     'name': 'Niagara St / Tecumseth St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.641389,
#     'lon': -79.404444,
#     'altitude': 0.0,
#     'address': 'Niagara St / Tecumseth St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-272-3286'},
#    {'station_id': '7123',
#     'name': '424 Wellington St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.643834,
#     'lon': -79.396649,
#     'altitude': 0.0,
#     'address': '424 Wellington St W',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-272-4047'},
#    {'station_id': '7124',
#     'name': 'Dundas St E / Broadview Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.662365,
#     'lon': -79.351104,
#     'altitude': 0.0,
#     'address': 'Dundas St E / Broadview Ave',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-669-4283'},
#    {'station_id': '7126',
#     'name': 'Yonge St / Yorkville Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.671944,
#     'lon': -79.387778,
#     'altitude': 0.0,
#     'address': 'Yonge St / Yorkville Ave',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-719-3941'},
#    {'station_id': '7127',
#     'name': 'Bay St / Davenport Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.672829,
#     'lon': -79.390592,
#     'altitude': 0.0,
#     'address': 'Bay St / Davenport Rd',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-201-6479'},
#    {'station_id': '7128',
#     'name': 'Yonge St / Aylmer Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.675492,
#     'lon': -79.388858,
#     'altitude': 0.0,
#     'address': 'Yonge St / Aylmer Ave',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-6641'},
#    {'station_id': '7129',
#     'name': 'Davenport Rd / Avenue Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.674991,
#     'lon': -79.396273,
#     'altitude': 0.0,
#     'address': 'Davenport Rd / Avenue Rd',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-992-7074'},
#    {'station_id': '7130',
#     'name': 'Pears Av / Avenue Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.675481,
#     'lon': -79.397359,
#     'altitude': 0.0,
#     'address': 'Pears Av / Avenue Rd',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-6906'},
#    {'station_id': '7131',
#     'name': 'Taddle Creek Park',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66986,
#     'lon': -79.398443,
#     'altitude': 0.0,
#     'address': 'Taddle Creek Park',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-309-1691'},
#    {'station_id': '7132',
#     'name': 'Kendal Ave / Spadina Rd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.670318,
#     'lon': -79.405181,
#     'altitude': 0.0,
#     'address': 'Kendal Ave / Spadina Rd',
#     'capacity': 8,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-7095'},
#    {'station_id': '7133',
#     'name': 'Summerhill Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.681944,
#     'lon': -79.390556,
#     'altitude': 0.0,
#     'address': 'Summerhill Station',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-328-4512'},
#    {'station_id': '7134',
#     'name': 'Marlborough Ave / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.68,
#     'lon': -79.391111,
#     'altitude': 0.0,
#     'address': 'Marlborough Ave / Yonge St',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-6918'},
#    {'station_id': '7135',
#     'name': 'Hanna Ave / Liberty St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.638333,
#     'lon': -79.419722,
#     'altitude': 0.0,
#     'address': 'Hanna Ave / Liberty St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-280-9962'},
#    {'station_id': '7136',
#     'name': 'Queen St W / Close Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.640634,
#     'lon': -79.435841,
#     'altitude': 0.0,
#     'address': 'Queen St W / Close Ave',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-624-8559'},
#    {'station_id': '7137',
#     'name': 'Davenport Rd / Bathurst St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.676667,
#     'lon': -79.416111,
#     'altitude': 0.0,
#     'address': 'Davenport Rd / Bathurst St',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '647-641-6859'},
#    {'station_id': '7138',
#     'name': 'Davenport Rd / Christie St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.675278,
#     'lon': -79.423889,
#     'altitude': 0.0,
# ...
#     'groups': None,
#     'obcn': '437-688-8745'},
#    {'station_id': '7441',
#     'name': '111 Pacific Avenue',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.65716,
#     'lon': -79.46478,
#     'altitude': 0.0,
#     'address': '111 Pacific Avenue',
#     'post_code': '12445',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7443',
#     'name': 'St Clarens Ave / Bloor St W SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.6583,
#     'lon': -79.4416,
#     'altitude': 0.0,
#     'address': '1251 Bloor St W',
#     'post_code': 'M6H 1N6',
#     'capacity': 20,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': ['SMART MAP FRAME'],
#     'obcn': ''},
#    {'station_id': '7444',
#     'name': 'Clendenan Ave / Annette St (SMART)',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.6607,
#     'lon': -79.4713,
#     'altitude': 0.0,
#     'address': '382 Clendenan Ave',
#     'post_code': 'M6P 2X6',
#     'capacity': 20,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': ['SMART MAP FRAME'],
#     'obcn': ''},
#    {'station_id': '7445',
#     'name': 'Coxwell Ave/ Eastwood Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6734,
#     'lon': -79.3185,
#     'altitude': 0.0,
#     'address': '265 Coxwell Ave',
#     'post_code': 'M4L 3B5',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7446',
#     'name': 'Orchard Park',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66882,
#     'lon': -79.31408,
#     'altitude': 0.0,
#     'address': '1987 Dundas St E',
#     'post_code': 'M4L 1M7',
#     'capacity': 18,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2385'},
#    {'station_id': '7447',
#     'name': 'Trent Ave/Danforth Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.68931,
#     'lon': -79.29562,
#     'altitude': 0.0,
#     'address': '2795 Danforth Ave',
#     'post_code': 'M4C 1M2',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2458'},
#    {'station_id': '7448',
#     'name': 'Goodwood Park Cres / Milburn Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.694657,
#     'lon': -79.295201,
#     'altitude': 0.0,
#     'address': '53 Goodwood Park Crescent',
#     'post_code': 'M4C2G5',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2392'},
#    {'station_id': '7449',
#     'name': 'Cosburn Ave / Cedarvale Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6972,
#     'lon': -79.3145,
#     'altitude': 0.0,
#     'address': '888 Cosburn Ave',
#     'post_code': 'M4C 4K7',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7450',
#     'name': 'Carlaw Ave / Danforth Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6783,
#     'lon': -79.3474,
#     'altitude': 0.0,
#     'address': '557 Danforth Ave',
#     'post_code': 'M4K 1P7',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7451',
#     'name': 'Western Battery Rd/Pirandello St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64013,
#     'lon': -79.41414,
#     'altitude': 0.0,
#     'address': '65 Western Battery Rd',
#     'post_code': 'M6K 3S4',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2559'},
#    {'station_id': '7452',
#     'name': 'Bleecker St / St James St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66939,
#     'lon': -79.37437,
#     'altitude': 0.0,
#     'address': '325 Bleecker St',
#     'post_code': 'M4X 1M2',
#     'capacity': 20,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2078'},
#    {'station_id': '7453',
#     'name': 'Jarvis St / Maitland Pl',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.66477,
#     'lon': -79.37726,
#     'altitude': 0.0,
#     'address': '469 Jarvis St',
#     'post_code': 'M4Y 2G8',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-243-6154'},
#    {'station_id': '7454',
#     'name': 'Pottery Rd / Lower Don River Trail',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6882762,
#     'lon': -79.3620992,
#     'altitude': 0.0,
#     'address': '165 Pottery Rd',
#     'post_code': 'M4K 2B9',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2781'},
#    {'station_id': '7455',
#     'name': 'E.T. Seton Park (Eglinton/Leslie)',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.7159578,
#     'lon': -79.3511823,
#     'altitude': 0.0,
#     'address': '1000 Eglinton Ave E',
#     'post_code': 'M4P 1A2',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7456',
#     'name': 'Belmont St / Davenport Rd SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.67474,
#     'lon': -79.39265,
#     'altitude': 0.0,
#     'address': '105 Belmont St',
#     'post_code': 'M5R 1P8',
#     'capacity': 12,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-243-6382'},
#    {'station_id': '7457',
#     'name': "Queen's Park Cres W / Hoskin Ave",
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6651997,
#     'lon': -79.3939726,
#     'altitude': 0.0,
#     'address': '2 Hoskin Ave',
#     'post_code': 'M5S 1H7',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-243-6418'},
#    {'station_id': '7458',
#     'name': 'Church St / Lombard',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6516,
#     'lon': -79.37533,
#     'altitude': 0.0,
#     'address': '100 Church St',
#     'post_code': 'M5C 3H9',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977576'},
#    {'station_id': '7459',
#     'name': 'St Clair Ave W / Winona Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.680334,
#     'lon': -79.431553,
#     'altitude': 0.0,
#     'address': '829 St. Clair Ave W',
#     'post_code': 'M6C 1C2',
#     'capacity': 31,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2434'},
#    {'station_id': '7460',
#     'name': 'High Park Outdoor Pool',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.649502,
#     'lon': -79.46519,
#     'altitude': 0.0,
#     'address': '1873 Bloor St W',
#     'post_code': 'M6R 2Z3',
#     'capacity': 27,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977626'},
#    {'station_id': '7461',
#     'name': 'High Park Amphitheatre',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.64631,
#     'lon': -79.462323,
#     'altitude': 0.0,
#     'address': '1873 Bloor St W',
#     'post_code': 'M6R 2Z3',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977501'},
#    {'station_id': '7462',
#     'name': 'Richmond St E / Yonge St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.651695,
#     'lon': -79.378217,
#     'altitude': 0.0,
#     'address': '157 Yonge St',
#     'post_code': 'M5C 1X7',
#     'capacity': 17,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-243-6481'},
#    {'station_id': '7463',
#     'name': 'Adelaide St W / Brant St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6463181,
#     'lon': -79.3971483,
#     'altitude': 0.0,
#     'address': '405 Adelaide St W',
#     'post_code': 'M5V 1S4',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-1537'},
#    {'station_id': '7465',
#     'name': 'Russell Hill Rd / St Clair Ave W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.685417,
#     'lon': -79.40836,
#     'altitude': 0.0,
#     'address': '262 St Clair Ave W',
#     'post_code': 'M4V 1R8',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2514'},
#    {'station_id': '7467',
#     'name': 'Lower Simcoe St / Bremner Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6426439,
#     'lon': -79.3840216,
#     'altitude': 0.0,
#     'address': '75 Lower Simcoe St',
#     'post_code': 'M5J 3A6',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2849'},
#    {'station_id': '7468',
#     'name': 'Front St / Simcoe St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6443755,
#     'lon': -79.3871195,
#     'altitude': 0.0,
#     'address': '270 Front St W',
#     'post_code': 'M5V 2W6',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2882'},
#    {'station_id': '7469',
#     'name': 'Wellington St W / York St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6467334,
#     'lon': -79.3830164,
#     'altitude': 0.0,
#     'address': '100 Wellington St W',
#     'post_code': 'M5J 2R2',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-2670'},
#    {'station_id': '7470',
#     'name': 'York St/Bremner Blvd',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.642,
#     'lon': -79.3807,
#     'altitude': 0.0,
#     'address': '15 York St',
#     'post_code': 'M5J 0A3',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72975919'},
#    {'station_id': '7471',
#     'name': 'Lakeshore Blvd W/Alexander St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6187,
#     'lon': -79.4867,
#     'altitude': 0.0,
#     'address': '2300 Lakeshore Blvd W',
#     'post_code': 'M8V 1B4',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72975976'},
#    {'station_id': '7472',
#     'name': 'Dundas St E / Victoria St Lane',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6563482,
#     'lon': -79.37904,
#     'altitude': 0.0,
#     'address': '38 Dundas St E',
#     'post_code': 'M5B 1B8',
#     'capacity': 40,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-1547'},
#    {'station_id': '7473',
#     'name': 'Strachan Ave / Adelaide St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6433484,
#     'lon': -79.4121529,
#     'altitude': 0.0,
#     'address': '127 Strachan Ave',
#     'post_code': 'M6J 2S7',
#     'capacity': 16,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-1546'},
#    {'station_id': '7474',
#     'name': 'Clarence Square',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6440297,
#     'lon': -79.3928816,
#     'altitude': 0.0,
#     'address': '25 Clarence Square',
#     'post_code': 'M5V 1H1',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-244-1303'},
#    {'station_id': '7475',
#     'name': 'Jarvis St/Richmond St E',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.652892,
#     'lon': -79.372764,
#     'altitude': 0.0,
#     'address': '115 Jarvis St',
#     'post_code': 'M5C 2H6',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-241-5732'},
#    {'station_id': '7476',
#     'name': 'Symington Ave/ Dupont St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6653823,
#     'lon': -79.4511529,
#     'altitude': 0.0,
#     'address': '1507 Dupont St',
#     'post_code': 'M6P 3S3',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7477',
#     'name': 'Campbell Ave / Sarnia Ave - SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.663,
#     'lon': -79.44844,
#     'altitude': 0.0,
#     'address': '225 Campbell Ave',
#     'post_code': 'M6P 3V5',
#     'capacity': 20,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-241-5622'},
#    {'station_id': '7478',
#     'name': 'Ellis Ave / The Queensway',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6386038,
#     'lon': -79.4669917,
#     'altitude': 0.0,
#     'address': '42 Ellis Ave',
#     'post_code': 'M6S 2X1',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977667'},
#    {'station_id': '7479',
#     'name': 'Jane Station',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.649515,
#     'lon': -79.484407,
#     'altitude': 0.0,
#     'address': '16 Jane St',
#     'post_code': 'M6S 3Y2',
#     'capacity': 15,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977592'},
#    {'station_id': '7480',
#     'name': 'Beresford Ave / Bloor St W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6515,
#     'lon': -79.47717,
#     'altitude': 0.0,
#     'address': '263 Beresford Ave',
#     'post_code': 'M6S 3B4',
#     'capacity': 14,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '437-241-5714'},
#    {'station_id': '7481',
#     'name': 'Westmount Rd / St Clair Ave W',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6785456,
#     'lon': -79.4421139,
#     'altitude': 0.0,
#     'address': '1145 St Clair Ave W',
#     'post_code': 'M6E 1B1',
#     'capacity': 7,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7482',
#     'name': 'Danforth Ave / Sibley Ave',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.6901847,
#     'lon': -79.2927198,
#     'altitude': 0.0,
#     'address': '3003 Danforth Ave',
#     'post_code': 'M4C 1M9',
#     'capacity': 11,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977220'},
#    {'station_id': '7483',
#     'name': 'Kingston Rd/Main St',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.6787711,
#     'lon': -79.2979378,
#     'altitude': 0.0,
#     'address': '637 Kingston Rd',
#     'post_code': 'M4E 1R3',
#     'capacity': 12,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': '72977402'},
#    {'station_id': '7486',
#     'name': 'Gerrard St E/Ted Reeve Dr',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.68454,
#     'lon': -79.297615,
#     'altitude': 0.0,
#     'address': '2230 Gerrard St E',
#     'post_code': 'M4E 2E1',
#     'capacity': 23,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7487',
#     'name': 'Eastwood Rd/Woodbine Ave - SMART',
#     'physical_configuration': 'SMARTMAPFRAME',
#     'lat': 43.6763,
#     'lon': -79.3092,
#     'altitude': 0.0,
#     'address': '290 Eastwood Rd',
#     'post_code': 'M4E 2H8',
#     'capacity': 12,
#     'rental_methods': ['KEY', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''},
#    {'station_id': '7492',
#     'name': 'Lakeshore Blvd E/ Bonnycastle St',
#     'physical_configuration': 'REGULAR',
#     'lat': 43.3851,
#     'lon': -79.2142,
#     'altitude': 0.0,
#     'address': '259 Lakeshore Blvd E',
#     'post_code': 'M5A 3T7',
#     'capacity': 19,
#     'rental_methods': ['KEY', 'CREDITCARD', 'TRANSITCARD', 'PHONE'],
#     'groups': None,
#     'obcn': ''}]}}

# %%
station_status
# Out:
# {'last_updated': 1562737809,
#  'ttl': 25,
#  'data': {'stations': [{'station_id': '7000',
#     'num_bikes_available': 28,
#     'num_bikes_available_types': {'mechanical': 28, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737572,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7001',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737696,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7002',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737603,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7003',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737601,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7004',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737679,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7005',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737787,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7006',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737574,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7007',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737582,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7008',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737687,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7009',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737648,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7010',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737613,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7011',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737585,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7012',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737569,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7013',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737682,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7014',
#     'num_bikes_available': 16,
#     'num_bikes_available_types': {'mechanical': 16, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737647,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7015',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737750,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7016',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737767,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7017',
#     'num_bikes_available': 15,
#     'num_bikes_available_types': {'mechanical': 15, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737636,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7018',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737671,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7019',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737788,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7020',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737552,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7021',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737761,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7022',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 26,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737679,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7023',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737571,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7024',
#     'num_bikes_available': 18,
#     'num_bikes_available_types': {'mechanical': 18, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737596,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7025',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737656,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7026',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737780,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7027',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737593,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7028',
#     'num_bikes_available': 14,
#     'num_bikes_available_types': {'mechanical': 14, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737701,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7029',
#     'num_bikes_available': 11,
#     'num_bikes_available_types': {'mechanical': 11, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737635,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7030',
#     'num_bikes_available': 21,
#     'num_bikes_available_types': {'mechanical': 21, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 44,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737668,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7031',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737730,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7032',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737712,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7033',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737586,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7034',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737578,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7035',
#     'num_bikes_available': 18,
#     'num_bikes_available_types': {'mechanical': 18, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737703,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7036',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737672,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7037',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737576,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7038',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737568,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7039',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 23,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737764,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7040',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737603,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7041',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737582,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7042',
#     'num_bikes_available': 27,
#     'num_bikes_available_types': {'mechanical': 27, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737647,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7043',
#     'num_bikes_available': 11,
#     'num_bikes_available_types': {'mechanical': 11, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 4,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737661,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7044',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737619,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7045',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737763,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7046',
#     'num_bikes_available': 11,
#     'num_bikes_available_types': {'mechanical': 11, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 0,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737662,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7047',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 21,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737804,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7048',
#     'num_bikes_available': 29,
#     'num_bikes_available_types': {'mechanical': 29, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737633,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7049',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737601,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7050',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737550,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7051',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737611,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7052',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737673,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7053',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737702,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7054',
#     'num_bikes_available': 8,
#     'num_bikes_available_types': {'mechanical': 8, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737687,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7055',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737573,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7056',
#     'num_bikes_available': 20,
#     'num_bikes_available_types': {'mechanical': 20, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737798,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7057',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737750,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7058',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737574,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7059',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737794,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7060',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737793,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7061',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737557,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7062',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737745,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7063',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737791,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7064',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737553,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7065',
#     'num_bikes_available': 11,
#     'num_bikes_available_types': {'mechanical': 11, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737548,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7066',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737802,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7067',
#     'num_bikes_available': 30,
#     'num_bikes_available_types': {'mechanical': 30, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 2,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737599,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7068',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 6,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737685,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7069',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737724,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7070',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737627,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7071',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737622,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7072',
#     'num_bikes_available': 8,
#     'num_bikes_available_types': {'mechanical': 8, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737618,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7073',
#     'num_bikes_available': 15,
#     'num_bikes_available_types': {'mechanical': 15, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737622,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7074',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737773,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7075',
#     'num_bikes_available': 26,
#     'num_bikes_available_types': {'mechanical': 26, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737636,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7076',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 10,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737757,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7077',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 19,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737598,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7078',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737588,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7079',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 10,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737555,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7083',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737569,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7084',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737617,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7085',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737725,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7086',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737804,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7087',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737646,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7088',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737612,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7089',
#     'num_bikes_available': 8,
#     'num_bikes_available_types': {'mechanical': 8, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737682,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7090',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737664,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7091',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737580,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7092',
#     'num_bikes_available': 8,
#     'num_bikes_available_types': {'mechanical': 8, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737641,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7093',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737784,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7094',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737700,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7095',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737798,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7096',
#     'num_bikes_available': 18,
#     'num_bikes_available_types': {'mechanical': 18, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737807,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7097',
#     'num_bikes_available': 14,
#     'num_bikes_available_types': {'mechanical': 14, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737764,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7098',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737784,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7099',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737625,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7100',
#     'num_bikes_available': 14,
#     'num_bikes_available_types': {'mechanical': 14, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737652,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7101',
#     'num_bikes_available': 15,
#     'num_bikes_available_types': {'mechanical': 15, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737563,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7102',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737780,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7103',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737693,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7104',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737682,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7105',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737797,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7106',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737545,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7107',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737599,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7108',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737623,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7109',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 4,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737677,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7110',
#     'num_bikes_available': 15,
#     'num_bikes_available_types': {'mechanical': 15, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737559,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7111',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737588,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7112',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 3,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737732,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7113',
#     'num_bikes_available': 12,
#     'num_bikes_available_types': {'mechanical': 12, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737743,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7114',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737693,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7115',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 7,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737576,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7116',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737548,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7117',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737581,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7118',
#     'num_bikes_available': 11,
#     'num_bikes_available_types': {'mechanical': 11, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 6,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737584,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7119',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737679,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7120',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737751,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7121',
#     'num_bikes_available': 12,
#     'num_bikes_available_types': {'mechanical': 12, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737805,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7122',
#     'num_bikes_available': 14,
#     'num_bikes_available_types': {'mechanical': 14, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737772,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7123',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737649,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7124',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 1,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737550,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7126',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737665,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7127',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 15,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737611,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7128',
#     'num_bikes_available': 6,
#     'num_bikes_available_types': {'mechanical': 6, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737604,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7129',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737623,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7130',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737693,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7131',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737551,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7132',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 1,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
# ...
#    {'station_id': '7444',
#     'num_bikes_available': 14,
#     'num_bikes_available_types': {'mechanical': 14, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 4,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737713,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7445',
#     'num_bikes_available': 18,
#     'num_bikes_available_types': {'mechanical': 18, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737782,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7446',
#     'num_bikes_available': 18,
#     'num_bikes_available_types': {'mechanical': 18, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737805,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7447',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737779,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7448',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737779,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7449',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737685,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7450',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737699,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7451',
#     'num_bikes_available': 21,
#     'num_bikes_available_types': {'mechanical': 21, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737729,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7452',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737581,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7453',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 16,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737641,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7454',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737751,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7455',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 27,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737547,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7456',
#     'num_bikes_available': 1,
#     'num_bikes_available_types': {'mechanical': 1, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737570,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7457',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 23,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737688,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7458',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737574,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7459',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 13,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737636,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7460',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 22,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737773,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7461',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 2,
#     'num_docks_available': 15,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737630,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7462',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 14,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737633,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7463',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737712,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7465',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 17,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737618,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7467',
#     'num_bikes_available': 3,
#     'num_bikes_available_types': {'mechanical': 3, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737620,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7468',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 11,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737569,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7469',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 20,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737687,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7470',
#     'num_bikes_available': 7,
#     'num_bikes_available_types': {'mechanical': 7, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737722,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7471',
#     'num_bikes_available': 12,
#     'num_bikes_available_types': {'mechanical': 12, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737622,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7472',
#     'num_bikes_available': 8,
#     'num_bikes_available_types': {'mechanical': 8, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 32,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737550,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7473',
#     'num_bikes_available': 9,
#     'num_bikes_available_types': {'mechanical': 9, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 7,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737566,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7474',
#     'num_bikes_available': 13,
#     'num_bikes_available_types': {'mechanical': 13, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737571,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7475',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737742,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7476',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 1,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737729,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7477',
#     'num_bikes_available': 17,
#     'num_bikes_available_types': {'mechanical': 17, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 3,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737739,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7478',
#     'num_bikes_available': 19,
#     'num_bikes_available_types': {'mechanical': 19, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737798,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7479',
#     'num_bikes_available': 10,
#     'num_bikes_available_types': {'mechanical': 10, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 5,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737579,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7480',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 12,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737565,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7481',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 2,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737399,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7482',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 9,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737654,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7483',
#     'num_bikes_available': 4,
#     'num_bikes_available_types': {'mechanical': 4, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 8,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737697,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7486',
#     'num_bikes_available': 5,
#     'num_bikes_available_types': {'mechanical': 5, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737782,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7487',
#     'num_bikes_available': 2,
#     'num_bikes_available_types': {'mechanical': 2, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 10,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737700,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7492',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 1,
#     'num_docks_available': 18,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 1,
#     'is_returning': 1,
#     'last_reported': 1562737765,
#     'is_charging_station': False,
#     'status': 'IN_SERVICE'},
#    {'station_id': '7498',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 0,
#     'is_charging_station': False,
#     'status': 'NOT_IN_SERVICE'},
#    {'station_id': '7499',
#     'num_bikes_available': 0,
#     'num_bikes_available_types': {'mechanical': 0, 'ebike': 0},
#     'num_bikes_disabled': 0,
#     'num_docks_available': 0,
#     'num_docks_disabled': 0,
#     'is_installed': 1,
#     'is_renting': 0,
#     'is_returning': 0,
#     'last_reported': 0,
#     'is_charging_station': False,
#     'status': 'NOT_IN_SERVICE'}]}}

# %%
stid = station_info['data']['stations']

# %%
df_st = pd.DataFrame(stid)
df_st.head()
# Out:
#                            address  altitude  capacity cross_street groups  \
# 0     Fort York  Blvd / Capreol Ct       0.0        31          NaN   None
# 1  Lower Jarvis St / The Esplanade       0.0        15          NaN   None
# 2       St. George St / Bloor St W       0.0        19          NaN   None
# 3         Madison Ave / Bloor St W       NaN        15          NaN   None
# 4          University Ave / Elm St       NaN        11          NaN   None
#
#          lat        lon                             name          obcn  \
# 0  43.639832 -79.395954     Fort York  Blvd / Capreol Ct  647-643-9607
# 1  43.647992 -79.370907  Lower Jarvis St / The Esplanade  416-617-9576
# 2  43.667333 -79.399429       St. George St / Bloor St W  647-643-9615
# 3  43.667158 -79.402761         Madison Ave / Bloor St W  647-631-4587
# 4  43.656518 -79.389099          University Ave / Elm St  647-643-9673
#
#   physical_configuration post_code                         rental_methods  \
# 0                REGULAR       NaN  [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 1                REGULAR       NaN  [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 2                REGULAR       NaN  [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 3                REGULAR       NaN  [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 4                REGULAR       NaN  [KEY, CREDITCARD, TRANSITCARD, PHONE]
#
#   station_id
# 0       7000
# 1       7001
# 2       7002
# 3       7003
# 4       7004

# %%
df_st.columns
# Out:
# Index(['address', 'altitude', 'capacity', 'cross_street', 'groups', 'lat',
#        'lon', 'name', 'obcn', 'physical_configuration', 'post_code',
#        'rental_methods', 'station_id'],
#       dtype='object')

# %%
df_st = df_st[['station_id','name','rental_methods']].set_index('station_id')
df_st.head()
# Out:
#                                        name  \
# station_id
# 7000           Fort York  Blvd / Capreol Ct
# 7001        Lower Jarvis St / The Esplanade
# 7002             St. George St / Bloor St W
# 7003               Madison Ave / Bloor St W
# 7004                University Ave / Elm St
#
#                                    rental_methods
# station_id
# 7000        [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 7001        [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 7002        [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 7003        [KEY, CREDITCARD, TRANSITCARD, PHONE]
# 7004        [KEY, CREDITCARD, TRANSITCARD, PHONE]

# %%
df_rider_Q417 = pd.read_csv(r'C:\Users\yfawz\OneDrive\Desktop\2017 Data\Bikeshare Ridership (2017 Q4).csv')
df_rider_Q317 = pd.read_csv(r'C:\Users\yfawz\OneDrive\Desktop\2017 Data\Bikeshare Ridership (2017 Q3).csv') 
df_rider_Q217 = pd.read_csv(r'C:\Users\yfawz\OneDrive\Desktop\2017 Data\Bikeshare Ridership (2017 Q2).csv')
df_rider_Q117 = pd.read_csv(r'C:\Users\yfawz\OneDrive\Desktop\2017 Data\Bikeshare Ridership (2017 Q1).csv')

# %%
df_rider_Q117.head()
# Out:
#    trip_id trip_start_time trip_stop_time  trip_duration_seconds  \
# 0   712382   1/1/2017 0:00  1/1/2017 0:03                    223
# 1   712383   1/1/2017 0:00  1/1/2017 0:05                    279
# 2   712384   1/1/2017 0:05  1/1/2017 0:29                   1394
# 3   712385   1/1/2017 0:07  1/1/2017 0:21                    826
# 4   712386   1/1/2017 0:08  1/1/2017 0:12                    279
#
#    from_station_id                  from_station_name  to_station_id  \
# 0             7051  Wellesley St E / Yonge St Green P           7089
# 1             7143           Kendal Ave / Bernard Ave           7154
# 2             7113       Parliament St / Aberdeen Ave           7199
# 3             7077                 College Park South           7010
# 4             7079              McGill St / Church St           7047
#
#                  to_station_name user_type
# 0           Church St  / Wood St    Member
# 1        Bathurst Subway Station    Member
# 2      College St W / Markham St    Member
# 3        King St W / Spadina Ave    Member
# 4  University Ave / Gerrard St W    Member

# %% [markdown]
# #  We need to make sure that all columns in all DataFrames are the same

# %%
df_rider_Q117.columns
# Out:
# Index(['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds',
#        'from_station_id', 'from_station_name', 'to_station_id',
#        'to_station_name', 'user_type'],
#       dtype='object')

# %%
df_rider_Q117.columns == df_rider_Q217.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
df_rider_Q117.columns == df_rider_Q317.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-b819755e596d> in <module>
# ----> 1 df_rider_Q117.columns == df_rider_Q317.columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#      68         if isinstance(other, (np.ndarray, Index, ABCSeries)):
#      69             if other.ndim > 0 and len(self) != len(other):
# ---> 70                 raise ValueError('Lengths must match to compare')
#      71
#      72         if is_object_dtype(self) and not isinstance(self, ABCMultiIndex):
#
# ValueError: Lengths must match to compare

# %%
df_rider_Q317.columns == df_rider_Q417.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True])

# %%
df_rider_Q317.columns
# Out:
# Index(['trip_id', 'trip_start_time', 'trip_stop_time', 'trip_duration_seconds',
#        'from_station_name', 'to_station_name', 'user_type'],
#       dtype='object')

# %% [markdown]
# # It seem that Q1 and Q2 data have the same columns while Q3 and Q4 have 2 columns missing(relative to Q1 and Q2) which are station id's 'to' and 'from'.
# # We can add those to the dataframes from the stations data.

# %%
names = [n for n in df_st['name']]
names[0] = 'Fort York  Blvd / Capreol Crt'

# %%
st_id = [id for id in df_st.index]

# %%
dic = {}
for n, ids in zip(names,st_id):
    dic[n] = ids

# %%
# Out:
# True

# %%
from_nameQ3 = [name for name in df_rider_Q317['from_station_name']]

# %%
from_idQ3 = [dic[name] for name in from_nameQ3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-223-4e1e8d2f28fb> in <module>
# ----> 1 from_idQ3 = [dic[name] for name in from_nameQ3]
#       2
#
# <ipython-input-223-4e1e8d2f28fb> in <listcomp>(.0)
# ----> 1 from_idQ3 = [dic[name] for name in from_nameQ3]
#       2
#
# KeyError: 'Michael Sweet Ave / St. Patrick St'

# %%
from_idQ3 = [df_st[df_st['name'] == name] for name in from_nameQ3]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-200-e5b27d2b4b54> in <module>
#       1 from_nameQ3 = [name for name in df_rider_Q317['from_station_name']]
# ----> 2 from_idQ3 = [df_st[df_st['name'] == name] for name in from_nameQ3]
#
# <ipython-input-200-e5b27d2b4b54> in <listcomp>(.0)
#       1 from_nameQ3 = [name for name in df_rider_Q317['from_station_name']]
# ----> 2 from_idQ3 = [df_st[df_st['name'] == name] for name in from_nameQ3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
# -> 2969         return self._take(indexer, axis=0)
#    2970
#    2971     def _getitem_multilevel(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _take(self, indices, axis, is_copy)
#    3357         new_data = self._data.take(indices,
#    3358                                    axis=self._get_block_manager_axis(axis),
# -> 3359                                    verify=True)
#    3360         result = self._constructor(new_data).__finalize__(self)
#    3361
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1348         new_labels = self.axes[axis].take(indexer)
#    1349         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 1350                                     axis=axis, allow_dups=True)
#    1351
#    1352     def merge(self, other, lsuffix='', rsuffix=''):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    1237         new_axes = list(self.axes)
#    1238         new_axes[axis] = new_axis
# -> 1239         return self.__class__(new_blocks, new_axes)
#    1240
#    1241     def _slice_take_blocks_ax0(self, slice_or_indexer, fill_tuple=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     116         self._consolidate_check()
#     117
# --> 118         self._rebuild_blknos_and_blklocs()
#     119
#     120     def make_empty(self, axes=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _rebuild_blknos_and_blklocs(self)
#     196             rl = blk.mgr_locs
#     197             new_blknos[rl.indexer] = blkno
# --> 198             new_blklocs[rl.indexer] = np.arange(len(rl))
#     199
#     200         if (new_blknos == -1).any():
#
# KeyboardInterrupt:

# %%
from_idQ3

# %%
to_nameQ3 = df_rider_Q317['to_station_name'] 
from_nameQ4 = df_rider_Q417['from_station_name']
to_nameQ4 = df_rider_Q417['to_station_name']

# %%
len(from_nameQ3)

# %%
df_rider_Q117
# Out:
#         trip_id   trip_start_time    trip_stop_time  trip_duration_seconds  \
# 0        712382     1/1/2017 0:00     1/1/2017 0:03                    223
# 1        712383     1/1/2017 0:00     1/1/2017 0:05                    279
# 2        712384     1/1/2017 0:05     1/1/2017 0:29                   1394
# 3        712385     1/1/2017 0:07     1/1/2017 0:21                    826
# 4        712386     1/1/2017 0:08     1/1/2017 0:12                    279
# 5        712387     1/1/2017 0:12     1/1/2017 0:22                    571
# 6        712388     1/1/2017 0:15     1/1/2017 0:33                   1084
# 7        712389     1/1/2017 0:15     1/1/2017 0:21                    307
# 8        712390     1/1/2017 0:20     1/1/2017 0:31                    647
# 9        712391     1/1/2017 0:23     1/1/2017 0:27                    217
# 10       712392     1/1/2017 0:28     1/1/2017 0:36                    467
# 11       712393     1/1/2017 0:28     1/1/2017 0:43                    880
# 12       712394     1/1/2017 0:31     1/1/2017 0:35                    228
# 13       712395     1/1/2017 0:33     1/1/2017 0:39                    361
# 14       712396     1/1/2017 0:38     1/1/2017 0:42                    227
# 15       712397     1/1/2017 0:53     1/1/2017 0:59                    354
# 16       712398     1/1/2017 0:55     1/1/2017 1:05                    591
# 17       712399     1/1/2017 0:59     1/1/2017 1:02                    169
# 18       712400     1/1/2017 0:59     1/1/2017 1:07                    451
# 19       712401     1/1/2017 1:02     1/1/2017 1:17                    920
# 20       712402     1/1/2017 1:07     1/1/2017 1:11                    256
# 21       712403     1/1/2017 1:12     1/1/2017 1:19                    398
# 22       712404     1/1/2017 1:14     1/1/2017 1:30                    982
# 23       712405     1/1/2017 1:29     1/1/2017 1:33                    261
# 24       712406     1/1/2017 1:31     1/1/2017 1:34                    182
# 25       712407     1/1/2017 1:31     1/1/2017 1:44                    780
# 26       712408     1/1/2017 1:32     1/1/2017 1:51                   1183
# 27       712409     1/1/2017 1:32     1/1/2017 1:40                    474
# 28       712410     1/1/2017 1:40     1/1/2017 1:48                    473
# 29       712411     1/1/2017 1:43     1/1/2017 2:00                    999
# ...         ...               ...               ...                    ...
# 132093   868621  31/03/2017 23:06  31/03/2017 23:10                    181
# 132094   868624  31/03/2017 23:08  31/03/2017 23:12                    268
# 132095   868625  31/03/2017 23:08  31/03/2017 23:20                    735
# 132096   868632  31/03/2017 23:10  31/03/2017 23:14                    224
# 132097   868633  31/03/2017 23:11  31/03/2017 23:14                    155
# 132098   868634  31/03/2017 23:11  31/03/2017 23:20                    531
# 132099   868639  31/03/2017 23:13  31/03/2017 23:28                    872
# 132100   868640  31/03/2017 23:14  31/03/2017 23:29                    941
# 132101   868643  31/03/2017 23:14  31/03/2017 23:17                    164
# 132102   868645  31/03/2017 23:15  31/03/2017 23:19                    240
# 132103   868646  31/03/2017 23:17  31/03/2017 23:40                   1374
# 132104   868647  31/03/2017 23:18  31/03/2017 23:26                    448
# 132105   868648  31/03/2017 23:22  31/03/2017 23:28                    362
# 132106   868649  31/03/2017 23:25  31/03/2017 23:29                    252
# 132107   868650  31/03/2017 23:26  31/03/2017 23:29                    208
# 132108   868651  31/03/2017 23:27  31/03/2017 23:31                    246
# 132109   868652  31/03/2017 23:32  31/03/2017 23:37                    299
# 132110   868653  31/03/2017 23:33  31/03/2017 23:48                    903
# 132111   868654  31/03/2017 23:34  31/03/2017 23:46                    685
# 132112   868655  31/03/2017 23:37  31/03/2017 23:44                    410
# 132113   868656  31/03/2017 23:37  31/03/2017 23:50                    770
# 132114   868657  31/03/2017 23:38  31/03/2017 23:52                    858
# 132115   868658  31/03/2017 23:41     1/4/2017 0:02                   1308
# 132116   868659  31/03/2017 23:43  31/03/2017 23:51                    465
# 132117   868660  31/03/2017 23:45     1/4/2017 0:08                   1422
# 132118   868705  31/03/2017 23:49     1/4/2017 0:09                   1222
# 132119   868661  31/03/2017 23:49  31/03/2017 23:57                    489
# 132120   868662  31/03/2017 23:49  31/03/2017 23:57                    442
# 132121   868663  31/03/2017 23:52     1/4/2017 0:10                   1116
# 132122   868664  31/03/2017 23:54  31/03/2017 23:56                    155
#
#         from_station_id                            from_station_name  \
# 0                  7051            Wellesley St E / Yonge St Green P
# 1                  7143                     Kendal Ave / Bernard Ave
# 2                  7113                 Parliament St / Aberdeen Ave
# 3                  7077                           College Park South
# 4                  7079                        McGill St / Church St
# 5                  7021                           Bay St / Albert St
# 6                  7161                    Beverly St / College St W
# 7                  7195                      Ulster St / Bathurst St
# 8                  7017                     Widmer St / Adelaide St
# 9                  7017                     Widmer St / Adelaide St
# 10                 7009                        King St E / Jarvis St
# 11                 7032                    Augusta Ave / Dundas St W
# 12                 7177              East Liberty St / Pirandello St
# 13                 7045                         Bond St / Queen St E
# 14                 7158                      King St W / Stafford St
# 15                 7022                       Simcoe St / Queen St W
# 16                 7077                           College Park South
# 17                 7028                         Gould St / Mutual St
# 18                 7038                         Dundas St / Yonge St
# 19                 7130                    Davenport Rd / Bedford Rd
# 20                 7042                 Sherbourne St / Wellesley St
# 21                 7160                     King St W / Tecumseth St
# 22                 7004                      University Ave / Elm St
# 23                 7163                           Yonge St / Wood St
# 24                 7164  Victoria St / Gould St (Ryerson University)
# 25                 7050            Richmond St E / Jarvis St Green P
# 26                 7133                           Summerhill Station
# 27                 7192                      Harbord St / Clinton St
# 28                 7070         25 York St (ACC/Union Station South)
# 29                 7059                   Front St W / Blue Jays Way
# ...                 ...                                          ...
# 132093             7077                           College Park South
# 132094             7101          Lower Sherbourne St / The Esplanade
# 132095             7009                        King St E / Jarvis St
# 132096             7063                     Queens Park / Bloor St W
# 132097             7094                              Chester Station
# 132098             7032                    Augusta Ave / Dundas St W
# 132099             7012      Elizabeth St / Edward St (Bus Terminal)
# 132100             7046                   Niagara St / Richmond St W
# 132101             7162                     Hayter St / Laplante Ave
# 132102             7041                         Edward St / Yonge St
# 132103             7095                  Danforth Ave / Ellerbeck St
# 132104             7030                      Bay St / Wellesley St W
# 132105             7050            Richmond St E / Jarvis St Green P
# 132106             7123                         424 Wellington St. W
# 132107             7073                   Bremner Blvd / Spadina Ave
# 132108             7205            Rusholme Park Cres / College St W
# 132109             7123                         424 Wellington St. W
# 132110             7041                         Edward St / Yonge St
# 132111             7069                     Queen St W / Spadina Ave
# 132112             7123                         424 Wellington St. W
# 132113             7060                    Princess St / Adelaide St
# 132114             7010                      King St W / Spadina Ave
# 132115             7126                     Yonge St / Yorkville Ave
# 132116             7064                             51 Parliament St
# 132117             7036                       Trinity St /Front St E
# 132118             7029                          Bay St / Bloor St W
# 132119             7006              Bay St / College St (East Side)
# 132120             7006              Bay St / College St (East Side)
# 132121             7057                  Simcoe St / Wellington St W
# 132122             7014   Sherbourne St / Carlton St (Allan Gardens)
#
#         to_station_id                              to_station_name user_type
# 0                7089                         Church St  / Wood St    Member
# 1                7154                      Bathurst Subway Station    Member
# 2                7199                    College St W / Markham St    Member
# 3                7010                      King St W / Spadina Ave    Member
# 4                7047                University Ave / Gerrard St W    Member
# 5                7046                   Niagara St / Richmond St W    Member
# 6                7176                 Bathurst St / Fort York Blvd    Member
# 7                7037                    Bathurst St / Dundas St W    Member
# 8                7101          Lower Sherbourne St / The Esplanade    Member
# 9                7005                   University Ave / King St W    Member
# 10               7016      Bay St / Queens Quay W (Ferry Terminal)    Member
# 11               7070         25 York St (ACC/Union Station South)    Member
# 12               7158                      King St W / Stafford St    Member
# 13               7060                    Princess St / Adelaide St    Member
# 14               7177              East Liberty St / Pirandello St    Member
# 15               7033                                Union Station    Member
# 16               7101          Lower Sherbourne St / The Esplanade    Member
# 17               7164  Victoria St / Gould St (Ryerson University)    Member
# 18               7065                  Dundas St E / Parliament St    Member
# 19               7038                         Dundas St / Yonge St    Member
# 20               7031                      Jarvis St / Isabella St    Member
# 21               7054               Navy Wharf Ct. / Bremner Blvd.    Member
# 22               7164  Victoria St / Gould St (Ryerson University)    Member
# 23               7041                         Edward St / Yonge St    Member
# 24               7045                         Bond St / Queen St E    Member
# 25               7043              Queens Quay W / Lower Simcoe St    Member
# 26               7049                     Queen St W / Portland St    Member
# 27               7205            Rusholme Park Cres / College St W    Casual
# 28               7000                Fort York  Blvd / Capreol Crt    Member
# 29               7208             80 Clinton St (North of College)    Member
# ...               ...                                          ...       ...
# 132093           7047                University Ave / Gerrard St W    Member
# 132094           7013                     Scott St / The Esplanade    Member
# 132095           7027                    Beverly  St / Dundas St W    Member
# 132096           7026                       Bay St / St. Joseph St    Member
# 132097           7095                  Danforth Ave / Ellerbeck St    Member
# 132098           7066                 Willcocks St / St. George St    Member
# 132099           7155                      Bathurst St / Lennox St    Member
# 132100           7152                   Ossington Ave / Bloor St W    Member
# 132101           7095                  Danforth Ave / Ellerbeck St    Member
# 132102           7006              Bay St / College St (East Side)    Member
# 132103           7078                      College St W / Major St    Member
# 132104           7033                                Union Station    Member
# 132105           7064                             51 Parliament St    Member
# 132106           7000                Fort York  Blvd / Capreol Crt    Member
# 132107           7010                      King St W / Spadina Ave    Member
# 132108           7193                   Queen St W / Gladstone Ave    Member
# 132109           7176                 Bathurst St / Fort York Blvd    Member
# 132110           7061                     Bloor St / Brunswick Ave    Member
# 132111           7026                       Bay St / St. Joseph St    Member
# 132112           7071         161 Bleecker St (South of Wellesley)    Member
# 132113           7017                     Widmer St / Adelaide St     Member
# 132114           7190                   St. George St / Hoskin Ave    Member
# 132115           7035                   Queen St W / Ossington Ave    Member
# 132116           7050            Richmond St E / Jarvis St Green P    Member
# 132117           7199                    College St W / Markham St    Member
# 132118           7017                     Widmer St / Adelaide St     Member
# 132119           7066                 Willcocks St / St. George St    Member
# 132120           7066                 Willcocks St / St. George St    Member
# 132121           7023                     College St W / Borden St    Member
# 132122           7113                 Parliament St / Aberdeen Ave    Member
#
# [132123 rows x 9 columns]

# %%
df_rider_Q117.groupby(['from_station_id']).count()['trip_id'].sort_values().plot(kind='bar')

# %%
df_rider_Q117.groupby(['from_station_id']).count()['trip_id'].sort_values()
# Out:
# from_station_id
# 7086      19
# 7083      26
# 7181      26
# 7085      37
# 7092      55
# 7147      64
# 7178      70
# 7130      73
# 7087      87
# 7137      91
# 7194      96
# 7084      96
# 7138      97
# 7091     101
# 7134     102
# 7197     110
# 7173     110
# 7122     116
# 7150     117
# 7198     123
# 7088     124
# 7090     128
# 7116     137
# 7117     140
# 7216     141
# 7128     143
# 7209     144
# 7174     145
# 7127     145
# 7141     148
#         ...
# 7058    1174
# 7073    1231
# 7005    1271
# 7003    1289
# 7062    1294
# 7002    1334
# 7059    1401
# 7029    1406
# 7027    1415
# 7022    1490
# 7077    1502
# 7021    1508
# 7019    1519
# 7060    1549
# 7161    1567
# 7007    1586
# 7028    1631
# 7020    1681
# 7066    1690
# 7026    1704
# 7039    1708
# 7042    1738
# 7017    1757
# 7049    1767
# 7030    2001
# 7038    2005
# 7010    2023
# 7057    2091
# 7006    2159
# 7033    2408
# Name: trip_id, Length: 200, dtype: int64

# %%
df_st.loc['7033']
# Out:
# name                                      Union Station
# address                                   Union Station
# rental_methods    [KEY, CREDITCARD, TRANSITCARD, PHONE]
# Name: 7033, dtype: object

# %%
df_rider_Q117.groupby(['to_station_id']).count()['trip_id'].sort_values().plot(kind='bar')

# %%
df_rider_Q117.groupby(['from_station_id'])['trip_duration_seconds'].mean().sort_values().plot(kind='bar')

# %%
from_to_pairs = df_rider_Q117.groupby(['from_station_id','to_station_id']).count()['trip_id']

# %%
from_to_pairs.sort_values(ascending=False)
# Out:
# from_station_id  to_station_id
# 7059             7033             252
# 7010             7057             237
# 7123             7033             200
# 7057             7010             199
# 7007             7057             191
# 7030             7033             175
# 7010             7033             169
# 7028             7048             167
# 7030             7052             157
# 7006             7033             152
# 7057             7161             151
# 7042             7060             148
# 7161             7057             145
# 7006             7161             140
# 7066             7033             137
# 7002             7066             132
# 7162             7012             132
# 7027             7038             128
# 7007             7006             127
# 7017             7060             127
# 7029             7030             126
# 7033             7039             124
# 7020             7033             121
# 7022             7039             121
# 7042             7051             120
# 7021             7033             119
# 7033             7123             115
# 7028             7033             115
# 7051             7042             114
# 7021             7006             114
#                                  ...
# 7096             7167               1
#                  7164               1
#                  7163               1
#                  7132               1
#                  7120               1
# 7097             7071               1
# 7096             7101               1
#                  7091               1
#                  7090               1
#                  7088               1
#                  7086               1
#                  7078               1
# 7097             7004               1
#                  7014               1
#                  7019               1
#                  7021               1
#                  7025               1
#                  7026               1
#                  7032               1
#                  7034               1
#                  7040               1
#                  7046               1
#                  7047               1
#                  7048               1
#                  7049               1
#                  7051               1
#                  7052               1
#                  7060               1
#                  7064               1
# 7074             7068               1
# Name: trip_id, Length: 18269, dtype: int64

# %%
df_st.loc['7010']
# Out:
# name                        Simcoe St / Wellington St 1
# address                     Simcoe St / Wellington St 1
# rental_methods    [KEY, CREDITCARD, TRANSITCARD, PHONE]
# Name: 7057, dtype: object

# %%
df_rider_Q117.tail()
# Out:
#         trip_id   trip_start_time    trip_stop_time  trip_duration_seconds  \
# 132118   868705  31/03/2017 23:49     1/4/2017 0:09                   1222
# 132119   868661  31/03/2017 23:49  31/03/2017 23:57                    489
# 132120   868662  31/03/2017 23:49  31/03/2017 23:57                    442
# 132121   868663  31/03/2017 23:52     1/4/2017 0:10                   1116
# 132122   868664  31/03/2017 23:54  31/03/2017 23:56                    155
#
#         from_station_id                           from_station_name  \
# 132118             7029                         Bay St / Bloor St W
# 132119             7006             Bay St / College St (East Side)
# 132120             7006             Bay St / College St (East Side)
# 132121             7057                 Simcoe St / Wellington St W
# 132122             7014  Sherbourne St / Carlton St (Allan Gardens)
#
#         to_station_id               to_station_name user_type
# 132118           7017      Widmer St / Adelaide St     Member
# 132119           7066  Willcocks St / St. George St    Member
# 132120           7066  Willcocks St / St. George St    Member
# 132121           7023      College St W / Borden St    Member
# 132122           7113  Parliament St / Aberdeen Ave    Member

# %%
df_rider_Q117['trip_start_time'] = pd.to_datetime(df_rider_Q117['trip_start_time'])

# %%
mor = df_rider_Q117[(df_rider_Q117['trip_start_time'].dt.hour >= 5) & (df_rider_Q117['trip_start_time'].dt.hour <= 10)]

# %%
mor.sort_values('trip_start_time').groupby('to_station_id').count()['trip_id'].sort_values().plot(kind='bar')
